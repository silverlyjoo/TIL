# %% [markdown]
# # 가상화폐 시세 판단하기

# %% [markdown]
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
# |Key Name        |     Description|
# |---|---|
# |opeing_price    |최근 24시간 내 시작 거래금액|
# |closing_price   |최근 24시간 내 마지막 거래금액|
# |min_price       |최근 24시간 내 최저 거래금액|
# |max_price       |최근 24시간 내 최고 거래금액|

# %%
import requests
from pprint import pprint
btc = requests.get('https://api.bithumb.com/public/ticker/btc').json()['data']
pprint(btc)
# Out:
# {'24H_fluctate': '-23000',
#  '24H_fluctate_rate': '-0.53',
#  'average_price': '4301844.3651',
#  'buy_price': '4284000',
#  'closing_price': '4286000',
#  'date': '1546566502366',
#  'max_price': '4339000',
#  'min_price': '4250000',
#  'opening_price': '4309000',
#  'sell_price': '4286000',
#  'units_traded': '18086.60964689',
#  'volume_1day': '18086.60964689',
#  'volume_7day': '56322.07366253'}

# %%
# 아래에 코드를 작성하세요.

op = int(btc['opening_price'])
ma_p = int(btc['min_price'])
mi_p = int(btc['max_price'])
st_price = op + abs(ma_p - mi_p)

if st_price > ma_p:
    print("상승장")
else:
    print("하락장")
# Out:
# 4398000
# 상승장

# %% [markdown]
# ## 모든 가상화폐 시세 판단하기
#
#
# > currrency dictionary에 담겨있는 모든 가상화폐 거래내역을 바탕으로 출력하라.
# >
# > 예외 처리에 유의하세요.
#
#
#
# ```
# 예시 출력)
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 하락장
# ETC 하락장
# XRP 상승장
# BCH 상승장
# ...
# ```

# %%
from pprint import pprint

currency = requests.get('https://api.bithumb.com/public/ticker/all').json()['data']
pprint(currency)
# Out:
# {'ABT': {'24H_fluctate': '-5.2',
#          '24H_fluctate_rate': '-5.14',
#          'average_price': '103.2471',
#          'buy_price': '95.8',
#          'closing_price': '95.8',
#          'max_price': '115',
#          'min_price': '94.1',
#          'opening_price': '101',
#          'sell_price': '97',
#          'units_traded': '11679627.00941732',
#          'volume_1day': '11679627.00941732',
#          'volume_7day': '50432375.121495697921657788'},
#  'ADA': {'24H_fluctate': '-2.4',
#          '24H_fluctate_rate': '-3.08',
#          'average_price': '77.1962',
#          'buy_price': '75.5',
#          'closing_price': '75.5',
#          'max_price': '79.3',
#          'min_price': '75.1',
#          'opening_price': '77.9',
#          'sell_price': '76.4',
#          'units_traded': '2094421.93586183',
#          'volume_1day': '2094421.93586183',
#          'volume_7day': '39798371.19645277'},
#  'ADD': [],
#  'AE': {'24H_fluctate': '-28',
#         '24H_fluctate_rate': '-1.69',
#         'average_price': '1632.7041',
#         'buy_price': '1603',
#         'closing_price': '1621',
#         'max_price': '1678',
#         'min_price': '1600',
#         'opening_price': '1649',
#         'sell_price': '1621',
#         'units_traded': '68540.45245548',
#         'volume_1day': '68540.45245548',
#         'volume_7day': '1899055.95406807896023566'},
#  'AMO': {'24H_fluctate': '-0.16',
#          '24H_fluctate_rate': '-9.03',
#          'average_price': '1.6986',
#          'buy_price': '1.6',
#          'closing_price': '1.61',
#          'max_price': '1.78',
#          'min_price': '1.56',
#          'opening_price': '1.77',
#          'sell_price': '1.61',
#          'units_traded': '719866644.15752508',
#          'volume_1day': '719866644.15752508',
#          'volume_7day': '24110882415.209791963542864948'},
#  'BAT': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-2.01',
#          'average_price': '147.1137',
#          'buy_price': '146',
#          'closing_price': '146',
#          'max_price': '154',
#          'min_price': '144',
#          'opening_price': '149',
#          'sell_price': '148',
#          'units_traded': '1516689.47449052',
#          'volume_1day': '1516689.47449052',
#          'volume_7day': '7020801.169710630100902915'},
#  'BCD': {'24H_fluctate': '-34',
#          '24H_fluctate_rate': '-3.27',
#          'average_price': '1016.3267',
#          'buy_price': '1003',
#          'closing_price': '1005',
#          'max_price': '1040',
#          'min_price': '997',
#          'opening_price': '1039',
#          'sell_price': '1005',
#          'units_traded': '119465.57448184',
#          'volume_1day': '119465.57448184',
#          'volume_7day': '1807577.86270526'},
#  'BCH': {'24H_fluctate': '-11700',
#          '24H_fluctate_rate': '-6.08',
#          'average_price': '183944.2418',
#          'buy_price': '180400',
#          'closing_price': '180500',
#          'max_price': '192200',
#          'min_price': '177300',
#          'opening_price': '192200',
#          'sell_price': '180500',
#          'units_traded': '47238.39316956',
#          'volume_1day': '47238.39316956',
#          'volume_7day': '553088.48935555'},
#  'BHPC': {'24H_fluctate': '-16',
#           '24H_fluctate_rate': '-1.75',
#           'average_price': '909.8546',
#           'buy_price': '896',
#           'closing_price': '895',
#           'max_price': '927',
#           'min_price': '890',
#           'opening_price': '911',
#           'sell_price': '905',
#           'units_traded': '475124.16335765',
#           'volume_1day': '475124.16335765',
#           'volume_7day': '8357645.407261527652769304'},
#  'BLACK': [],
#  'BSV': {'24H_fluctate': '-4250',
#          '24H_fluctate_rate': '-4.08',
#          'average_price': '100491.3303',
#          'buy_price': '99700',
#          'closing_price': '99750',
#          'max_price': '104400',
#          'min_price': '97400',
#          'opening_price': '104000',
#          'sell_price': '99750',
#          'units_traded': '23329.59319771',
#          'volume_1day': '23329.59319771',
#          'volume_7day': '269444.52296815'},
#  'BTC': {'24H_fluctate': '-46000',
#          '24H_fluctate_rate': '-1.06',
#          'average_price': '4301333.6177',
#          'buy_price': '4274000',
#          'closing_price': '4277000',
#          'max_price': '4339000',
#          'min_price': '4250000',
#          'opening_price': '4323000',
#          'sell_price': '4277000',
#          'units_traded': '18041.24336491',
#          'volume_1day': '18041.24336491',
#          'volume_7day': '56249.68540662'},
#  'BTG': {'24H_fluctate': '-480',
#          '24H_fluctate_rate': '-3.22',
#          'average_price': '14504.7363',
#          'buy_price': '14390',
#          'closing_price': '14400',
#          'max_price': '15040',
#          'min_price': '12970',
#          'opening_price': '14880',
#          'sell_price': '14400',
#          'units_traded': '22841687.35383701',
#          'volume_1day': '22841687.35383701',
#          'volume_7day': '98626917.43078745'},
#  'BZNT': {'24H_fluctate': '-0.5',
#           '24H_fluctate_rate': '-1.77',
#           'average_price': '27.9374',
#           'buy_price': '27.7',
#           'closing_price': '27.7',
#           'max_price': '29.3',
#           'min_price': '27',
#           'opening_price': '28.2',
#           'sell_price': '28',
#           'units_traded': '35338745.48264837',
#           'volume_1day': '35338745.48264837',
#           'volume_7day': '191409597.621133452831885565'},
#  'CHL': [],
#  'CMT': {'24H_fluctate': '-0.5',
#          '24H_fluctate_rate': '-1.42',
#          'average_price': '34.5766',
#          'buy_price': '33.9',
#          'closing_price': '34.6',
#          'max_price': '36.2',
#          'min_price': '32.4',
#          'opening_price': '35.1',
#          'sell_price': '34.6',
#          'units_traded': '4693179.21155042',
#          'volume_1day': '4693179.21155042',
#          'volume_7day': '36373457.702795702860476475'},
#  'CTXC': {'24H_fluctate': '-3',
#           '24H_fluctate_rate': '-2.50',
#           'average_price': '118.0544',
#           'buy_price': '115',
#           'closing_price': '117',
#           'max_price': '124',
#           'min_price': '113',
#           'opening_price': '120',
#           'sell_price': '117',
#           'units_traded': '1320677.15731294',
#           'volume_1day': '1320677.15731294',
#           'volume_7day': '11484514.776721014673753123'},
#  'DASH': {'24H_fluctate': '-3250',
#           '24H_fluctate_rate': '-3.46',
#           'average_price': '90821.2758',
#           'buy_price': '90300',
#           'closing_price': '90450',
#           'max_price': '93750',
#           'min_price': '88100',
#           'opening_price': '93700',
#           'sell_price': '90450',
#           'units_traded': '3773928.60023308',
#           'volume_1day': '3773928.60023308',
#           'volume_7day': '32121248.17752674'},
#  'ELF': {'24H_fluctate': '6',
#          '24H_fluctate_rate': '4.68',
#          'average_price': '132.2167',
#          'buy_price': '134',
#          'closing_price': '134',
#          'max_price': '139',
#          'min_price': '125',
#          'opening_price': '128',
#          'sell_price': '135',
#          'units_traded': '5099085.22080202',
#          'volume_1day': '5099085.22080202',
#          'volume_7day': '18443952.117588335405889591'},
#  'ENJ': {'24H_fluctate': '-1.8',
#          '24H_fluctate_rate': '-4.00',
#          'average_price': '44.0311',
#          'buy_price': '43.1',
#          'closing_price': '43.1',
#          'max_price': '45.7',
#          'min_price': '42.6',
#          'opening_price': '44.9',
#          'sell_price': '43.4',
#          'units_traded': '3473403.24424156',
#          'volume_1day': '3473403.24424156',
#          'volume_7day': '23035150.208258192816118614'},
#  'EOS': {'24H_fluctate': '-146',
#          '24H_fluctate_rate': '-4.65',
#          'average_price': '3046.4923',
#          'buy_price': '2990',
#          'closing_price': '2991',
#          'max_price': '3166',
#          'min_price': '2930',
#          'opening_price': '3137',
#          'sell_price': '2992',
#          'units_traded': '2397551.69719548',
#          'volume_1day': '2397551.69719548',
#          'volume_7day': '22716597.28025381'},
#  'EOSDAC': [],
#  'ETC': {'24H_fluctate': '-270',
#          '24H_fluctate_rate': '-4.53',
#          'average_price': '5780.1213',
#          'buy_price': '5670',
#          'closing_price': '5685',
#          'max_price': '5995',
#          'min_price': '5640',
#          'opening_price': '5955',
#          'sell_price': '5685',
#          'units_traded': '528077.32629124',
#          'volume_1day': '528077.32629124',
#          'volume_7day': '1869685.171114439873039507'},
#  'ETH': {'24H_fluctate': '-4200',
#          '24H_fluctate_rate': '-2.45',
#          'average_price': '168156.5711',
#          'buy_price': '167000',
#          'closing_price': '167000',
#          'max_price': '173800',
#          'min_price': '163500',
#          'opening_price': '171200',
#          'sell_price': '167100',
#          'units_traded': '580651.10008619',
#          'volume_1day': '580651.10008619',
#          'volume_7day': '1970912.035587088952984616'},
#  'ETHOS': {'24H_fluctate': '-18',
#            '24H_fluctate_rate': '-1.61',
#            'average_price': '1107.7564',
#            'buy_price': '1094',
#            'closing_price': '1095',
#            'max_price': '1177',
#            'min_price': '1050',
#            'opening_price': '1113',
#            'sell_price': '1095',
#            'units_traded': '255439.82987046',
#            'volume_1day': '255439.82987046',
#            'volume_7day': '6309355.46066809'},
#  'GNT': {'24H_fluctate': '-0.7',
#          '24H_fluctate_rate': '-0.90',
#          'average_price': '76.5266',
#          'buy_price': '75.5',
#          'closing_price': '76.3',
#          'max_price': '78.5',
#          'min_price': '75.3',
#          'opening_price': '77',
#          'sell_price': '76.2',
#          'units_traded': '1039356.04889068',
#          'volume_1day': '1039356.04889068',
#          'volume_7day': '37311327.099545753986240579'},
#  'GTO': {'24H_fluctate': '-1.1',
#          '24H_fluctate_rate': '-1.50',
#          'average_price': '74.117',
#          'buy_price': '72.1',
#          'closing_price': '72',
#          'max_price': '78.1',
#          'min_price': '71.2',
#          'opening_price': '73.1',
#          'sell_price': '72.9',
#          'units_traded': '2213795.48802207',
#          'volume_1day': '2213795.48802207',
#          'volume_7day': '24902508.93005879'},
#  'HC': {'24H_fluctate': '3',
#         '24H_fluctate_rate': '0.20',
#         'average_price': '1444.6319',
#         'buy_price': '1412',
#         'closing_price': '1433',
#         'max_price': '1512',
#         'min_price': '1380',
#         'opening_price': '1430',
#         'sell_price': '1433',
#         'units_traded': '81708.03733315',
#         'volume_1day': '81708.03733315',
#         'volume_7day': '888085.74850032'},
#  'HORUS': [],
#  'ICX': {'24H_fluctate': '1',
#          '24H_fluctate_rate': '0.34',
#          'average_price': '294.8996',
#          'buy_price': '291',
#          'closing_price': '291',
#          'max_price': '318',
#          'min_price': '281',
#          'opening_price': '290',
#          'sell_price': '294',
#          'units_traded': '2108167.94916089',
#          'volume_1day': '2108167.94916089',
#          'volume_7day': '5005815.059527308297395376'},
#  'INS': {'24H_fluctate': '20',
#          '24H_fluctate_rate': '6.04',
#          'average_price': '339.3898',
#          'buy_price': '350',
#          'closing_price': '351',
#          'max_price': '366',
#          'min_price': '316',
#          'opening_price': '331',
#          'sell_price': '351',
#          'units_traded': '4364718.7503279',
#          'volume_1day': '4364718.7503279',
#          'volume_7day': '11871274.9261243662'},
#  'IOST': {'24H_fluctate': '-0.11',
#           '24H_fluctate_rate': '-1.70',
#           'average_price': '6.3305',
#           'buy_price': '6.28',
#           'closing_price': '6.36',
#           'max_price': '6.52',
#           'min_price': '6.16',
#           'opening_price': '6.47',
#           'sell_price': '6.37',
#           'units_traded': '422369307.73424684',
#           'volume_1day': '422369307.73424684',
#           'volume_7day': '1445277134.82627073474677631'},
#  'ITC': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-2.14',
#          'average_price': '136.717',
#          'buy_price': '136',
#          'closing_price': '137',
#          'max_price': '141',
#          'min_price': '133',
#          'opening_price': '140',
#          'sell_price': '137',
#          'units_traded': '1501810.87794434',
#          'volume_1day': '1501810.87794434',
#          'volume_7day': '17661410.793570639705758781'},
#  'KNC': {'24H_fluctate': '-7',
#          '24H_fluctate_rate': '-3.80',
#          'average_price': '179.6004',
#          'buy_price': '176',
#          'closing_price': '177',
#          'max_price': '185',
#          'min_price': '173',
#          'opening_price': '184',
#          'sell_price': '177',
#          'units_traded': '819460.01055387',
#          'volume_1day': '819460.01055387',
#          'volume_7day': '7217732.282790646089975132'},
#  'LINK': {'24H_fluctate': '51',
#           '24H_fluctate_rate': '13.67',
#           'average_price': '403.0501',
#           'buy_price': '420',
#           'closing_price': '424',
#           'max_price': '446',
#           'min_price': '358',
#           'opening_price': '373',
#           'sell_price': '424',
#           'units_traded': '12448925.24835239',
#           'volume_1day': '12448925.24835239',
#           'volume_7day': '16575128.686441857328008566'},
#  'LOOM': {'24H_fluctate': '-2.5',
#           '24H_fluctate_rate': '-4.40',
#           'average_price': '57.6685',
#           'buy_price': '54.3',
#           'closing_price': '54.3',
#           'max_price': '63.8',
#           'min_price': '53.1',
#           'opening_price': '56.8',
#           'sell_price': '54.8',
#           'units_traded': '23801186.08896854',
#           'volume_1day': '23801186.08896854',
#           'volume_7day': '47015184.508444511561186799'},
#  'LRC': {'24H_fluctate': '-27',
#          '24H_fluctate_rate': '-4.57',
#          'average_price': '577.5783',
#          'buy_price': '562',
#          'closing_price': '563',
#          'max_price': '595',
#          'min_price': '563',
#          'opening_price': '590',
#          'sell_price': '563',
#          'units_traded': '133584.12498059',
#          'volume_1day': '133584.12498059',
#          'volume_7day': '2920561.661871617643527395'},
#  'LTC': {'24H_fluctate': '-870',
#          '24H_fluctate_rate': '-2.37',
#          'average_price': '35942.2549',
#          'buy_price': '35610',
#          'closing_price': '35730',
#          'max_price': '36920',
#          'min_price': '34940',
#          'opening_price': '36600',
#          'sell_price': '35710',
#          'units_traded': '12232.19719976',
#          'volume_1day': '12232.19719976',
#          'volume_7day': '176071.76442017'},
#  'MCO': {'24H_fluctate': '3',
#          '24H_fluctate_rate': '0.11',
#          'average_price': '2584.9886',
#          'buy_price': '2569',
#          'closing_price': '2622',
#          'max_price': '2645',
#          'min_price': '2533',
#          'opening_price': '2619',
#          'sell_price': '2623',
#          'units_traded': '804482.76880361',
#          'volume_1day': '804482.76880361',
#          'volume_7day': '1917843.15067829'},
#  'MEETONE': [],
#  'MITH': {'24H_fluctate': '-2.2',
#           '24H_fluctate_rate': '-3.08',
#           'average_price': '69.8612',
#           'buy_price': '68.9',
#           'closing_price': '69',
#           'max_price': '71.4',
#           'min_price': '68.3',
#           'opening_price': '71.2',
#           'sell_price': '69',
#           'units_traded': '9224432.51720668',
#           'volume_1day': '9224432.51720668',
#           'volume_7day': '106728486.19630550599621313'},
#  'OCN': {'24H_fluctate': '-0.22',
#          '24H_fluctate_rate': '-5.51',
#          'average_price': '3.8466',
#          'buy_price': '3.77',
#          'closing_price': '3.77',
#          'max_price': '4.04',
#          'min_price': '3.67',
#          'opening_price': '3.99',
#          'sell_price': '3.79',
#          'units_traded': '55097831.70378849',
#          'volume_1day': '55097831.70378849',
#          'volume_7day': '1602156605.471413560050201454'},
#  'OMG': {'24H_fluctate': '-35',
#          '24H_fluctate_rate': '-2.08',
#          'average_price': '1647.289',
#          'buy_price': '1643',
#          'closing_price': '1643',
#          'max_price': '1691',
#          'min_price': '1612',
#          'opening_price': '1678',
#          'sell_price': '1655',
#          'units_traded': '1247780.79754469',
#          'volume_1day': '1247780.79754469',
#          'volume_7day': '10925930.605121818906013623'},
#  'PAY': {'24H_fluctate': '-75',
#          '24H_fluctate_rate': '-4.14',
#          'average_price': '1787.9692',
#          'buy_price': '1736',
#          'closing_price': '1736',
#          'max_price': '1845',
#          'min_price': '1730',
#          'opening_price': '1811',
#          'sell_price': '1741',
#          'units_traded': '194712.36190496',
#          'volume_1day': '194712.36190496',
#          'volume_7day': '8390490.896237287598933692'},
#  'PIVX': {'24H_fluctate': '-46',
#           '24H_fluctate_rate': '-4.73',
#           'average_price': '939.7552',
#           'buy_price': '916',
#           'closing_price': '926',
#           'max_price': '973',
#           'min_price': '914',
#           'opening_price': '972',
#           'sell_price': '926',
#           'units_traded': '154966.95690544',
#           'volume_1day': '154966.95690544',
#           'volume_7day': '10439469.89094645'},
#  'PLY': {'24H_fluctate': '-0.7',
#          '24H_fluctate_rate': '-1.82',
#          'average_price': '38.1766',
#          'buy_price': '37.6',
#          'closing_price': '37.7',
#          'max_price': '40',
#          'min_price': '36.4',
#          'opening_price': '38.4',
#          'sell_price': '37.7',
#          'units_traded': '10162905.1871848',
#          'volume_1day': '10162905.1871848',
#          'volume_7day': '108943533.996038524'},
#  'POLY': {'24H_fluctate': '-5',
#           '24H_fluctate_rate': '-3.10',
#           'average_price': '157.4419',
#           'buy_price': '156',
#           'closing_price': '156',
#           'max_price': '162',
#           'min_price': '155',
#           'opening_price': '161',
#           'sell_price': '158',
#           'units_traded': '1215678.60529114',
#           'volume_1day': '1215678.60529114',
#           'volume_7day': '9967063.026797255355654461'},
#  'POWR': {'24H_fluctate': '-16',
#           '24H_fluctate_rate': '-2.96',
#           'average_price': '529',
#           'buy_price': '517',
#           'closing_price': '524',
#           'max_price': '545',
#           'min_price': '512',
#           'opening_price': '540',
#           'sell_price': '521',
#           'units_traded': '425422.28795944',
#           'volume_1day': '425422.28795944',
#           'volume_7day': '6128317.16743961'},
#  'PPT': {'24H_fluctate': '-11',
#          '24H_fluctate_rate': '-0.65',
#          'average_price': '1663.2155',
#          'buy_price': '1653',
#          'closing_price': '1670',
#          'max_price': '1691',
#          'min_price': '1621',
#          'opening_price': '1681',
#          'sell_price': '1669',
#          'units_traded': '37176.909',
#          'volume_1day': '37176.909',
#          'volume_7day': '689521.24376665'},
#  'PST': {'24H_fluctate': '-4',
#          '24H_fluctate_rate': '-3.53',
#          'average_price': '111.5359',
#          'buy_price': '109',
#          'closing_price': '109',
#          'max_price': '117',
#          'min_price': '107',
#          'opening_price': '113',
#          'sell_price': '110',
#          'units_traded': '822791.41176885',
#          'volume_1day': '822791.41176885',
#          'volume_7day': '9430901.297611780616582618'},
#  'QTUM': {'24H_fluctate': '-79',
#           '24H_fluctate_rate': '-3.07',
#           'average_price': '2495.2406',
#           'buy_price': '2486',
#           'closing_price': '2487',
#           'max_price': '2567',
#           'min_price': '2449',
#           'opening_price': '2566',
#           'sell_price': '2494',
#           'units_traded': '748417.75313422',
#           'volume_1day': '748417.75313422',
#           'volume_7day': '3124845.2860956'},
#  'RDN': {'24H_fluctate': '-38',
#          '24H_fluctate_rate': '-11.30',
#          'average_price': '311.9385',
#          'buy_price': '294',
#          'closing_price': '298',
#          'max_price': '345',
#          'min_price': '279',
#          'opening_price': '336',
#          'sell_price': '298',
#          'units_traded': '7301676.70569332',
#          'volume_1day': '7301676.70569332',
#          'volume_7day': '25517778.547742721353021321'},
#  'REP': {'24H_fluctate': '-2000',
#          '24H_fluctate_rate': '-2.03',
#          'average_price': '96904.9853',
#          'buy_price': '95400',
#          'closing_price': '96300',
#          'max_price': '99300',
#          'min_price': '94800',
#          'opening_price': '98300',
#          'sell_price': '96300',
#          'units_traded': '3685.91296683',
#          'volume_1day': '3685.91296683',
#          'volume_7day': '94140.077748120518075148'},
#  'RNT': {'24H_fluctate': '6',
#          '24H_fluctate_rate': '4.37',
#          'average_price': '145.5953',
#          'buy_price': '142',
#          'closing_price': '143',
#          'max_price': '183',
#          'min_price': '116',
#          'opening_price': '137',
#          'sell_price': '143',
#          'units_traded': '82488638.82895326',
#          'volume_1day': '82488638.82895326',
#          'volume_7day': '185564007.746942647476018077'},
#  'ROM': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '0.1264',
#          'buy_price': '0.12',
#          'closing_price': '0.13',
#          'max_price': '0.13',
#          'min_price': '0.12',
#          'opening_price': '0.13',
#          'sell_price': '0.13',
#          'units_traded': '42627168875.60489231',
#          'volume_1day': '42627168875.60489231',
#          'volume_7day': '216861685738.120281660303161222'},
#  'SALT': {'24H_fluctate': '-21',
#           '24H_fluctate_rate': '-7.36',
#           'average_price': '273.8434',
#           'buy_price': '264',
#           'closing_price': '264',
#           'max_price': '289',
#           'min_price': '262',
#           'opening_price': '285',
#           'sell_price': '266',
#           'units_traded': '1486791.51071115',
#           'volume_1day': '1486791.51071115',
#           'volume_7day': '12798589.11242145'},
#  'SNT': {'24H_fluctate': '-1',
#          '24H_fluctate_rate': '-0.85',
#          'average_price': '116.4898',
#          'buy_price': '115',
#          'closing_price': '116',
#          'max_price': '120',
#          'min_price': '112',
#          'opening_price': '117',
#          'sell_price': '116',
#          'units_traded': '1702466.67788952',
#          'volume_1day': '1702466.67788952',
#          'volume_7day': '24198458.578611629713343892'},
#  'STEEM': {'24H_fluctate': '-3',
#            '24H_fluctate_rate': '-0.16',
#            'average_price': '1825.497',
#            'buy_price': '1805',
#            'closing_price': '1838',
#            'max_price': '1875',
#            'min_price': '1784',
#            'opening_price': '1841',
#            'sell_price': '1838',
#            'units_traded': '75610.6620933',
#            'volume_1day': '75610.6620933',
#            'volume_7day': '1365910.7952473'},
#  'STRAT': {'24H_fluctate': '-1',
#            '24H_fluctate_rate': '-0.03',
#            'average_price': '2843.1392',
#            'buy_price': '2811',
#            'closing_price': '2884',
#            'max_price': '2919',
#            'min_price': '2751',
#            'opening_price': '2885',
#            'sell_price': '2875',
#            'units_traded': '24432.44115097',
#            'volume_1day': '24432.44115097',
#            'volume_7day': '487980.7504285'},
#  'THETA': {'24H_fluctate': '-0.8',
#            '24H_fluctate_rate': '-1.39',
#            'average_price': '58.0041',
#            'buy_price': '56',
#            'closing_price': '56.5',
#            'max_price': '62.8',
#            'min_price': '55.4',
#            'opening_price': '57.3',
#            'sell_price': '56.5',
#            'units_traded': '18102311.4928032',
#            'volume_1day': '18102311.4928032',
#            'volume_7day': '91921623.812888079266342968'},
#  'TMTG': {'24H_fluctate': '-0.23',
#           '24H_fluctate_rate': '-2.75',
#           'average_price': '8.2502',
#           'buy_price': '8.11',
#           'closing_price': '8.12',
#           'max_price': '8.41',
#           'min_price': '8.09',
#           'opening_price': '8.35',
#           'sell_price': '8.12',
#           'units_traded': '202686281.73692092',
#           'volume_1day': '202686281.73692092',
#           'volume_7day': '1483207734.948487940161481648'},
#  'TRUE': {'24H_fluctate': '18',
#           '24H_fluctate_rate': '6.14',
#           'average_price': '306.377',
#           'buy_price': '311',
#           'closing_price': '311',
#           'max_price': '337',
#           'min_price': '287',
#           'opening_price': '293',
#           'sell_price': '318',
#           'units_traded': '2218081.38983346',
#           'volume_1day': '2218081.38983346',
#           'volume_7day': '8412694.662813637773447992'},
#  'TRX': {'24H_fluctate': '0.1',
#          '24H_fluctate_rate': '0.45',
#          'average_price': '22.4333',
#          'buy_price': '22.3',
#          'closing_price': '22.3',
#          'max_price': '23.2',
#          'min_price': '21.8',
#          'opening_price': '22.2',
#          'sell_price': '22.4',
#          'units_traded': '220980011.02800232',
#          'volume_1day': '220980011.02800232',
#          'volume_7day': '940031860.92506475'},
#  'VET': {'24H_fluctate': '-0.19',
#          '24H_fluctate_rate': '-2.62',
#          'average_price': '7.1934',
#          'buy_price': '7.06',
#          'closing_price': '7.06',
#          'max_price': '7.35',
#          'min_price': '7.06',
#          'opening_price': '7.25',
#          'sell_price': '7.13',
#          'units_traded': '8080091.31138701',
#          'volume_1day': '8080091.31138701',
#          'volume_7day': '72340056.52486151956123794'},
#  'WAVES': {'24H_fluctate': '5',
#            '24H_fluctate_rate': '0.14',
#            'average_price': '3483.8363',
#            'buy_price': '3443',
#            'closing_price': '3459',
#            'max_price': '3550',
#            'min_price': '3419',
#            'opening_price': '3454',
#            'sell_price': '3477',
#            'units_traded': '175278.92031167',
#            'volume_1day': '175278.92031167',
#            'volume_7day': '2678650.77250588'},
#  'WAX': {'24H_fluctate': '-2',
#          '24H_fluctate_rate': '-1.86',
#          'average_price': '105.6142',
#          'buy_price': '105',
#          'closing_price': '105',
#          'max_price': '108',
#          'min_price': '104',
#          'opening_price': '107',
#          'sell_price': '106',
#          'units_traded': '853831.72129347',
#          'volume_1day': '853831.72129347',
#          'volume_7day': '17692031.09044218'},
#  'WET': {'24H_fluctate': '-0.2',
#          '24H_fluctate_rate': '-1.40',
#          'average_price': '14.08',
#          'buy_price': '13.9',
#          'closing_price': '14',
#          'max_price': '14.4',
#          'min_price': '13.9',
#          'opening_price': '14.2',
#          'sell_price': '14',
#          'units_traded': '18612483.51008711',
#          'volume_1day': '18612483.51008711',
#          'volume_7day': '194810795.677109116950969508'},
#  'WTC': {'24H_fluctate': '4',
#          '24H_fluctate_rate': '0.31',
#          'average_price': '1285.988',
#          'buy_price': '1267',
#          'closing_price': '1273',
#          'max_price': '1328',
#          'min_price': '1253',
#          'opening_price': '1269',
#          'sell_price': '1275',
#          'units_traded': '226641.59477532',
#          'volume_1day': '226641.59477532',
#          'volume_7day': '2368085.320817056649794688'},
#  'XEM': {'24H_fluctate': '-1.2',
#          '24H_fluctate_rate': '-1.63',
#          'average_price': '73.2312',
#          'buy_price': '72.3',
#          'closing_price': '72.3',
#          'max_price': '75.4',
#          'min_price': '72',
#          'opening_price': '73.5',
#          'sell_price': '72.8',
#          'units_traded': '2074808.81265356',
#          'volume_1day': '2074808.81265356',
#          'volume_7day': '21649925.62323651'},
#  'XLM': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-2.30',
#          'average_price': '128.1714',
#          'buy_price': '126',
#          'closing_price': '127',
#          'max_price': '131',
#          'min_price': '126',
#          'opening_price': '130',
#          'sell_price': '127',
#          'units_traded': '4785587.91492867',
#          'volume_1day': '4785587.91492867',
#          'volume_7day': '47719691.57589247'},
#  'XMR': {'24H_fluctate': '-1600',
#          '24H_fluctate_rate': '-2.80',
#          'average_price': '55959.8499',
#          'buy_price': '55400',
#          'closing_price': '55400',
#          'max_price': '57500',
#          'min_price': '55000',
#          'opening_price': '57000',
#          'sell_price': '55400',
#          'units_traded': '12870669.47251319',
#          'volume_1day': '12870669.47251319',
#          'volume_7day': '67957475.706224596036'},
#  'XRP': {'24H_fluctate': '-11',
#          '24H_fluctate_rate': '-2.66',
#          'average_price': '404.0812',
#          'buy_price': '400',
#          'closing_price': '401',
#          'max_price': '413',
#          'min_price': '397',
#          'opening_price': '412',
#          'sell_price': '401',
#          'units_traded': '46275603.53894696',
#          'volume_1day': '46275603.53894696',
#          'volume_7day': '473997315.01778227'},
#  'XVG': {'24H_fluctate': '-0.11',
#          '24H_fluctate_rate': '-1.38',
#          'average_price': '7.8694',
#          'buy_price': '7.76',
#          'closing_price': '7.86',
#          'max_price': '8.04',
#          'min_price': '7.72',
#          'opening_price': '7.97',
#          'sell_price': '7.86',
#          'units_traded': '5885501.15702363',
#          'volume_1day': '5885501.15702363',
#          'volume_7day': '51439691.33454364'},
#  'ZEC': {'24H_fluctate': '-1650',
#          '24H_fluctate_rate': '-2.45',
#          'average_price': '65702.0348',
#          'buy_price': '65350',
#          'closing_price': '65450',
#          'max_price': '67350',
#          'min_price': '64150',
#          'opening_price': '67100',
#          'sell_price': '65450',
#          'units_traded': '36023.61084304',
#          'volume_1day': '36023.61084304',
#          'volume_7day': '33685223.47652229'},
#  'ZIL': {'24H_fluctate': '-0.4',
#          '24H_fluctate_rate': '-1.76',
#          'average_price': '22.3708',
#          'buy_price': '22.2',
#          'closing_price': '22.2',
#          'max_price': '22.7',
#          'min_price': '22',
#          'opening_price': '22.6',
#          'sell_price': '22.3',
#          'units_traded': '19210626.50988188',
#          'volume_1day': '19210626.50988188',
#          'volume_7day': '456953117.521413354635'},
#  'ZRX': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '363.8577',
#          'buy_price': '359',
#          'closing_price': '360',
#          'max_price': '370',
#          'min_price': '356',
#          'opening_price': '360',
#          'sell_price': '360',
#          'units_traded': '993340.12815099',
#          'volume_1day': '993340.12815099',
#          'volume_7day': '5917679.394681677377380573'},
#  'date': '1546567959866'}

# %%
for key, value in currency.items():
    if type(value) == type(dict()):
        bdp = float(value['max_price']) - float(value['min_price'])
        if float(value['opening_price']) + bdp > float(value['max_price']):
            print(f'{key:5} 상승장')
        else:
            print(f'{key:5} 하락장')
# Out:
# BTC   상승장
# ETH   상승장
# DASH  상승장
# LTC   상승장
# ETC   상승장
# XRP   상승장
# BCH   상승장
# XMR   상승장
# ZEC   상승장
# QTUM  상승장
# BTG   상승장
# EOS   상승장
# ICX   상승장
# VET   상승장
# TRX   상승장
# ELF   상승장
# MITH  상승장
# MCO   상승장
# OMG   상승장
# KNC   상승장
# GNT   상승장
# ZIL   상승장
# ETHOS 상승장
# PAY   상승장
# WAX   상승장
# POWR  상승장
# LRC   상승장
# GTO   상승장
# STEEM 상승장
# STRAT 상승장
# ZRX   상승장
# REP   상승장
# AE    상승장
# XEM   상승장
# SNT   상승장
# ADA   상승장
# PPT   상승장
# CTXC  상승장
# CMT   상승장
# THETA 상승장
# WTC   상승장
# ITC   상승장
# TRUE  상승장
# ABT   상승장
# RNT   상승장
# PLY   상승장
# WAVES 상승장
# LINK  상승장
# ENJ   상승장
# PST   상승장
# SALT  상승장
# RDN   상승장
# LOOM  상승장
# BHPC  상승장
# PIVX  상승장
# INS   상승장
# BCD   상승장
# BZNT  상승장
# XLM   상승장
# OCN   상승장
# BSV   상승장
# TMTG  상승장
# BAT   상승장
# WET   상승장
# XVG   상승장
# IOST  상승장
# POLY  상승장
# HC    상승장
# ROM   상승장
# AMO   상승장
